# %%
import swimclub

# %%
swimclub.read_swim_data("Darius-13-100m-Fly.txt")
# aqui não funcionou o return mesmo depois de ter reimportado o módulo porque ele fica armaenado em cache
# então tive que reiniciar o kernel para funcionar
# o MÓDULO É COMPUTACIONALMENTE CUSTOSO
# Out:
# ('Darius',
#  '13',
#  '100m',
#  'Fly',
#  ['1:27.95', '1:21.07', '1:30.96', '1:23.22', '1:27.95', '1:28.30'],
#  '1:26.58')

# %%
data = swimclub.read_swim_data("Darius-13-100m-Fly.txt")
time = data[4]

# %%
time
# Out:
# ['1:27.95', '1:21.07', '1:30.96', '1:23.22', '1:27.95', '1:28.30']

# %%
swimmer, age, distance, stroke, time2, average = data

# %%
time2
# Out:
# ['1:27.95', '1:21.07', '1:30.96', '1:23.22', '1:27.95', '1:28.30']

# %%
swimclub.read_swim_data("Abi-10-100m-Back.txt")
# Out:
# ('Abi',
#  '10',
#  '100m',
#  'Back',
#  ['1:31.59', '1:26.55', '1:28.75', '1:39.79', '1:32.37'],
#  '1:31.81')

# %%
import os

# %%
swim_files = os.listdir(swimclub.FOLDER)

# %%
len(swim_files)
# Out:
# 60

# %%
print(swim_files)
# Out:
# ['Hannah-13-100m-Free.txt', 'Darius-13-100m-Back.txt', 'Owen-15-100m-Free.txt', 'Mike-15-100m-Free.txt', 'Hannah-13-100m-Back.txt', 'Mike-15-100m-Back.txt', 'Mike-15-100m-Fly.txt', 'Abi-10-50m-Back.txt', 'Ruth-13-200m-Free.txt', 'Tasmin-15-100m-Back.txt', 'Erika-15-100m-Free.txt', 'Ruth-13-200m-Back.txt', 'Abi-10-50m-Free.txt', 'Maria-9-50m-Free.txt', 'Elba-14-100m-Free.txt', 'Tasmin-15-100m-Free.txt', 'Abi-10-100m-Back.txt', 'Abi-10-50m-Breast.txt', 'Mike-15-200m-IM.txt', 'Ali-12-100m-Back.txt', 'Ruth-13-100m-Back.txt', 'Chris-17-100m-Back.txt', 'Ali-12-100m-Free.txt', 'Darius-13-100m-Breast.txt', 'Ruth-13-100m-Free.txt', 'Aurora-13-50m-Free.txt', 'Katie-9-100m-Breast.txt', 'Alison-14-100m-Breast.txt', 'Ruth-13-400m-Free.txt', 'Emma-13-100m-Free.txt', 'Calvin-9-50m-Fly.txt', 'Darius-13-100m-Fly.txt', 'Mike-15-200m-Free.txt', 'Emma-13-100m-Breast.txt', 'Tasmin-15-100m-Breast.txt', 'Blake-15-100m-Free.txt', 'Abi-10-100m-Breast.txt', 'Chris-17-100m-Breast.txt', 'Blake-15-100m-Back.txt'
# ...

# %%
print(dir(swim_files))
# Out:
# ['__add__', '__class__', '__class_getitem__', '__contains__', '__delattr__', '__delitem__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__iadd__', '__imul__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__rmul__', '__setattr__', '__setitem__', '__sizeof__', '__str__', '__subclasshook__', 'append', 'clear', 'copy', 'count', 'extend', 'index', 'insert', 'pop', 'remove', 'reverse', 'sort']

# %%
print(sorted(swim_files))
# Out:
# ['Abi-10-100m-Back.txt', 'Abi-10-100m-Breast.txt', 'Abi-10-50m-Back.txt', 'Abi-10-50m-Breast.txt', 'Abi-10-50m-Free.txt', 'Ali-12-100m-Back.txt', 'Ali-12-100m-Free.txt', 'Alison-14-100m-Breast.txt', 'Alison-14-100m-Free.txt', 'Aurora-13-50m-Free.txt', 'Bill-18-100m-Back.txt', 'Bill-18-200m-Back.txt', 'Blake-15-100m-Back.txt', 'Blake-15-100m-Fly.txt', 'Blake-15-100m-Free.txt', 'Calvin-9-50m-Back.txt', 'Calvin-9-50m-Fly.txt', 'Calvin-9-50m-Free.txt', 'Carl-15-100m-Back.txt', 'Chris-17-100m-Back.txt', 'Chris-17-100m-Breast.txt', 'Darius-13-100m-Back.txt', 'Darius-13-100m-Breast.txt', 'Darius-13-100m-Fly.txt', 'Darius-13-200m-IM.txt', 'Dave-17-100m-Free.txt', 'Dave-17-200m-Back.txt', 'Elba-14-100m-Free.txt', 'Emma-13-100m-Breast.txt', 'Emma-13-100m-Free.txt', 'Erika-15-100m-Breast.txt', 'Erika-15-100m-Free.txt', 'Erika-15-200m-Breast.txt', 'Hannah-13-100m-Back.txt', 'Hannah-13-100m-Free.txt', 'Katie-9-100m-Back.txt', 'Katie-9-100m-Breast.txt', 'Katie-9-100m-Free.txt', 'Katie-9-50m-Back.t
# ...

# %%
help(swim_files.remove)
#originalmente era para remover o ._DS_Store, mas não funcionou porque o arquivo não estava lá, codigo de remoção comentado abaixo

#swim_files.remove('.DS_Store')
# Out:
# Help on built-in function remove:
#
# remove(value, /) method of builtins.list instance
#     Remove first occurrence of value.
#
#     Raises ValueError if the value is not present.

# %%
for index, swim_file in enumerate(swim_files, 1):
    print(index,"Reading file:", swim_file)
    swimclub.read_swim_data(swim_file)
# Out:
# 1 Reading file: Hannah-13-100m-Free.txt
# 2 Reading file: Darius-13-100m-Back.txt
# 3 Reading file: Owen-15-100m-Free.txt
# 4 Reading file: Mike-15-100m-Free.txt
# 5 Reading file: Hannah-13-100m-Back.txt
# 6 Reading file: Mike-15-100m-Back.txt
# 7 Reading file: Mike-15-100m-Fly.txt
# 8 Reading file: Abi-10-50m-Back.txt
# 9 Reading file: Ruth-13-200m-Free.txt
# 10 Reading file: Tasmin-15-100m-Back.txt
# 11 Reading file: Erika-15-100m-Free.txt
# 12 Reading file: Ruth-13-200m-Back.txt
# 13 Reading file: Abi-10-50m-Free.txt
# 14 Reading file: Maria-9-50m-Free.txt
# 15 Reading file: Elba-14-100m-Free.txt
# 16 Reading file: Tasmin-15-100m-Free.txt
# 17 Reading file: Abi-10-100m-Back.txt
# 18 Reading file: Abi-10-50m-Breast.txt
# 19 Reading file: Mike-15-200m-IM.txt
# 20 Reading file: Ali-12-100m-Back.txt
# 21 Reading file: Ruth-13-100m-Back.txt
# 22 Reading file: Chris-17-100m-Back.txt
# 23 Reading file: Ali-12-100m-Free.txt
# 24 Reading file: Darius-13-100m-Breast.txt
# ...
